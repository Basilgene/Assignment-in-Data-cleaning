# %% [markdown]
# # Assignment 4

# %% [markdown]
# ## Data Cleaning

# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/USER/Downloads/messy_data.csv")      #messy_data.csv

# %%
data
# Out:
#        TrnsnID        Data  CusmrID  ProdtID ProdtName  Qutity   Prize  \
# 0         7402  03/17/2026      991     1045     Boo E       9  167.72
# 1         5835  26-01-2035      741     1040    Book J      18  193.27
# 2         2123  05/26/2035      933     1062     Bok N       5  126.39
# 3         8789  28-02-2036      641     1060    Book I       6   66.98
# 4          305  19-04-2023      123     1058    Book B      15   33.63
# 5         2532  19-08-2032      185     1090     Bok N      12  102.69
# 6         2996  04/03/2031      571     1086    Book D      15  176.27
# 7         7660  27-02-2031      172     1012    Book P      12   44.51
# 8         8225  26-05-2026      342     1098    Book P      11   72.57
# 9         4449  02/05/2030      614     1086    Book M       5   15.67
# 10        3621  05-08-2036      755     1051     Boo E      19  149.75
# 11        9211  07/18/2035      361     1020    Book O      14  140.04
# ...

# %%
data.head()
# Out:
#    TrnsnID        Data  CusmrID  ProdtID ProdtName  Qutity   Prize  TtlSales  \
# 0     7402  03/17/2026      991     1045     Boo E       9  167.72   2935.06
# 1     5835  26-01-2035      741     1040    Book J      18  193.27   4386.52
# 2     2123  05/26/2035      933     1062     Bok N       5  126.39   1948.46
# 3     8789  28-02-2036      641     1060    Book I       6   66.98   1757.26
# 4      305  19-04-2023      123     1058    Book B      15   33.63   2578.19
#
#   PaymentType  CusterAge
# 0         NaN         87
# 1  debit card         69
# 2        Cash         15
# 3        Cash         22
# 4        Cash         -1

# %%
data.shape
# Out:
# (10100, 10)

# %%
data.columns
# Out:
# Index(['TrnsnID', 'Data', 'CusmrID', 'ProdtID', 'ProdtName', 'Qutity', 'Prize',
#        'TtlSales', 'PaymentType', 'CusterAge'],
#       dtype='object')

# %% [markdown]
# ## 1. Duplicate Record

# %%
data["TrnsnID"].duplicated().value_counts()
# Out:
# False    10000
# True       100
# Name: TrnsnID, dtype: int64

# %%
data["Data"].duplicated().value_counts()
# Out:
# False    10000
# True       100
# Name: Data, dtype: int64

# %%
data["CusmrID"].duplicated().value_counts()
# Out:
# True     9101
# False     999
# Name: CusmrID, dtype: int64

# %%
data["ProdtName"].duplicated().value_counts()
# Out:
# True     10081
# False       19
# Name: ProdtName, dtype: int64

# %%
data["Qutity"].duplicated().value_counts()
# Out:
# True     10075
# False       25
# Name: Qutity, dtype: int64

# %%
data["Prize"].duplicated().value_counts()
# Out:
# False    7822
# True     2278
# Name: Prize, dtype: int64

# %%
data["TtlSales"].duplicated().value_counts()
# Out:
# False    9909
# True      191
# Name: TtlSales, dtype: int64

# %%
data["PaymentType"].duplicated().value_counts()
# Out:
# True     10093
# False        7
# Name: PaymentType, dtype: int64

# %%
data["CusterAge"].duplicated().value_counts()
# Out:
# True     9990
# False     110
# Name: CusterAge, dtype: int64

# %%
data.duplicated().sum()
# Out:
# 100

# %%
data = data.drop_duplicates(keep = 'last')

# %%
data
# Out:
#        TrnsnID        Data  CusmrID  ProdtID ProdtName  Qutity   Prize  \
# 0         7402  03/17/2026      991     1045     Boo E       9  167.72
# 1         5835  26-01-2035      741     1040    Book J      18  193.27
# 2         2123  05/26/2035      933     1062     Bok N       5  126.39
# 3         8789  28-02-2036      641     1060    Book I       6   66.98
# 4          305  19-04-2023      123     1058    Book B      15   33.63
# 5         2532  19-08-2032      185     1090     Bok N      12  102.69
# 6         2996  04/03/2031      571     1086    Book D      15  176.27
# 7         7660  27-02-2031      172     1012    Book P      12   44.51
# 8         8225  26-05-2026      342     1098    Book P      11   72.57
# 9         4449  02/05/2030      614     1086    Book M       5   15.67
# 10        3621  05-08-2036      755     1051     Boo E      19  149.75
# 11        9211  07/18/2035      361     1020    Book O      14  140.04
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 2. Missing Values

# %%
data.isna()
# Out:
#        TrnsnID   Data  CusmrID  ProdtID  ProdtName  Qutity  Prize  TtlSales  \
# 0        False  False    False    False      False   False  False     False
# 1        False  False    False    False      False   False  False     False
# 2        False  False    False    False      False   False  False     False
# 3        False  False    False    False      False   False  False     False
# 4        False  False    False    False      False   False  False     False
# 5        False  False    False    False      False   False  False     False
# 6        False  False    False    False      False   False  False     False
# 7        False  False    False    False      False   False  False     False
# 8        False  False    False    False      False   False  False     False
# 9        False  False    False    False      False   False  False     False
# 10       False  False    False    False      False   False  False     False
# ...

# %%
data.isna().sum()
# Out:
# TrnsnID           0
# Data              0
# CusmrID           0
# ProdtID           0
# ProdtName       994
# Qutity            0
# Prize             0
# TtlSales          0
# PaymentType    1439
# CusterAge         0
# dtype: int64

# %%
data.fillna(method = 'bfill', inplace = True)     ##backward fill to fill NAN
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\pandas\core\frame.py:4034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)

# %%
data.isna().sum()
# Out:
# TrnsnID        0
# Data           0
# CusmrID        0
# ProdtID        0
# ProdtName      0
# Qutity         0
# Prize          0
# TtlSales       0
# PaymentType    0
# CusterAge      0
# dtype: int64

# %% [markdown]
# ## 3. Consistent format for date

# %%
pd.to_datetime(data.Data)
# Out:
# 0       2026-03-17
# 1       2035-01-26
# 2       2035-05-26
# 3       2036-02-28
# 4       2023-04-19
# 5       2032-08-19
# 6       2031-04-03
# 7       2031-02-27
# 8       2026-05-26
# 9       2030-02-05
# 10      2036-05-08
# 11      2035-07-18
# 12      2032-04-10
# 13      2025-04-07
# 14      2029-12-12
# 15      2029-08-20
# 17      2032-08-16
# 18      2026-08-30
# 19      2031-11-13
# 21      2026-04-13
# 22      2032-09-13
# 23      2027-02-05
# 24      2033-07-12
# 25      2028-10-29
# 26      2029-12-10
# 27      2030-08-12
# 28      2036-08-21
# 29      2033-07-03
# 30      2026-01-09
# 31      2035-03-16
#            ...
# 10070   2024-12-14
# 10071   2025-10-05
# 10072   2025-08-24
# 10073   2025-01-23
# 10074   2029-04-08
# 10075   2034-12-25
# 10076   2028-01-06
# 10077   2025-01-30
# 10078   2023-08-22
# 10079   2025-04-12
# 10080   2024-04-01
# 10081   2031-06-20
# 10082   2030-05-22
# 10083   2032-07-24
# 10084   2023-06-07
# 10085   2033-01-23
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 0 to 10099
# Data columns (total 10 columns):
# TrnsnID        10000 non-null int64
# Data           10000 non-null object
# CusmrID        10000 non-null int64
# ProdtID        10000 non-null int64
# ProdtName      10000 non-null object
# Qutity         10000 non-null int64
# Prize          10000 non-null float64
# TtlSales       10000 non-null float64
# PaymentType    10000 non-null object
# CusterAge      10000 non-null int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 859.4+ KB

# %%
data.Data = pd.to_datetime(data.Data)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\pandas\core\generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
data.Data
# Out:
# 0       2026-03-17
# 1       2035-01-26
# 2       2035-05-26
# 3       2036-02-28
# 4       2023-04-19
# 5       2032-08-19
# 6       2031-04-03
# 7       2031-02-27
# 8       2026-05-26
# 9       2030-02-05
# 10      2036-05-08
# 11      2035-07-18
# 12      2032-04-10
# 13      2025-04-07
# 14      2029-12-12
# 15      2029-08-20
# 17      2032-08-16
# 18      2026-08-30
# 19      2031-11-13
# 21      2026-04-13
# 22      2032-09-13
# 23      2027-02-05
# 24      2033-07-12
# 25      2028-10-29
# 26      2029-12-10
# 27      2030-08-12
# 28      2036-08-21
# 29      2033-07-03
# 30      2026-01-09
# 31      2035-03-16
#            ...
# 10070   2024-12-14
# 10071   2025-10-05
# 10072   2025-08-24
# 10073   2025-01-23
# 10074   2029-04-08
# 10075   2034-12-25
# 10076   2028-01-06
# 10077   2025-01-30
# 10078   2023-08-22
# 10079   2025-04-12
# 10080   2024-04-01
# 10081   2031-06-20
# 10082   2030-05-22
# 10083   2032-07-24
# 10084   2023-06-07
# 10085   2033-01-23
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 0 to 10099
# Data columns (total 10 columns):
# TrnsnID        10000 non-null int64
# Data           10000 non-null datetime64[ns]
# CusmrID        10000 non-null int64
# ProdtID        10000 non-null int64
# ProdtName      10000 non-null object
# Qutity         10000 non-null int64
# Prize          10000 non-null float64
# TtlSales       10000 non-null float64
# PaymentType    10000 non-null object
# CusterAge      10000 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(5), object(2)
# memory usage: 859.4+ KB

# %% [markdown]
# ## 4. Standardizing the payment type Names

# %%
data.head()
# Out:
#    TrnsnID       Data  CusmrID  ProdtID ProdtName  Qutity   Prize  TtlSales  \
# 0     7402 2026-03-17      991     1045     Boo E       9  167.72   2935.06
# 1     5835 2035-01-26      741     1040    Book J      18  193.27   4386.52
# 2     2123 2035-05-26      933     1062     Bok N       5  126.39   1948.46
# 3     8789 2036-02-28      641     1060    Book I       6   66.98   1757.26
# 4      305 2023-04-19      123     1058    Book B      15   33.63   2578.19
#
#   PaymentType  CusterAge
# 0  debit card         87
# 1  debit card         69
# 2        Cash         15
# 3        Cash         22
# 4        Cash         -1

# %%
data['PaymentType'].unique()
# Out:
# array(['debit card', 'Cash', 'Debit', 'Credit', 'Credit Card', 'paypal'],
#       dtype=object)

# %%
data['PaymentType'].replace({'Debit': 'Debit Card', 'Credit': 'Credit Card'})
# Out:
# 0         debit card
# 1         debit card
# 2               Cash
# 3               Cash
# 4               Cash
# 5               Cash
# 6               Cash
# 7               Cash
# 8         Debit Card
# 9         Debit Card
# 10              Cash
# 11       Credit Card
# 12        Debit Card
# 13       Credit Card
# 14        debit card
# 15              Cash
# 17       Credit Card
# 18        Debit Card
# 19       Credit Card
# 21       Credit Card
# 22       Credit Card
# 23        debit card
# 24       Credit Card
# 25              Cash
# 26       Credit Card
# 27              Cash
# 28        debit card
# 29              Cash
# 30              Cash
# 31              Cash
#             ...
# 10070         paypal
# 10071    Credit Card
# 10072     debit card
# 10073     debit card
# 10074     debit card
# 10075         paypal
# 10076     Debit Card
# 10077         paypal
# 10078         paypal
# 10079    Credit Card
# 10080     debit card
# 10081    Credit Card
# ...

# %%
data['PaymentType'] = data['PaymentType'].replace({'Debit': 'Debit Card', 'Credit': 'Credit Card'})
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data
# Out:
#        TrnsnID       Data  CusmrID  ProdtID ProdtName  Qutity   Prize  \
# 0         7402 2026-03-17      991     1045     Boo E       9  167.72
# 1         5835 2035-01-26      741     1040    Book J      18  193.27
# 2         2123 2035-05-26      933     1062     Bok N       5  126.39
# 3         8789 2036-02-28      641     1060    Book I       6   66.98
# 4          305 2023-04-19      123     1058    Book B      15   33.63
# 5         2532 2032-08-19      185     1090     Bok N      12  102.69
# 6         2996 2031-04-03      571     1086    Book D      15  176.27
# 7         7660 2031-02-27      172     1012    Book P      12   44.51
# 8         8225 2026-05-26      342     1098    Book P      11   72.57
# 9         4449 2030-02-05      614     1086    Book M       5   15.67
# 10        3621 2036-05-08      755     1051     Boo E      19  149.75
# 11        9211 2035-07-18      361     1020    Book O      14  140.04
# ...

# %%
data['PaymentType'].unique()
# Out:
# array(['debit card', 'Cash', 'Debit Card', 'Credit Card', 'paypal'],
#       dtype=object)

# %% [markdown]
# ## 5. Nagative Values

# %%
data.head(50)
# Out:
#     TrnsnID       Data  CusmrID  ProdtID ProdtName  Qutity   Prize  TtlSales  \
# 0      7402 2026-03-17      991     1045     Boo E       9  167.72   2935.06
# 1      5835 2035-01-26      741     1040    Book J      18  193.27   4386.52
# 2      2123 2035-05-26      933     1062     Bok N       5  126.39   1948.46
# 3      8789 2036-02-28      641     1060    Book I       6   66.98   1757.26
# 4       305 2023-04-19      123     1058    Book B      15   33.63   2578.19
# 5      2532 2032-08-19      185     1090     Bok N      12  102.69    488.23
# 6      2996 2031-04-03      571     1086    Book D      15  176.27   4822.26
# 7      7660 2031-02-27      172     1012    Book P      12   44.51   4966.85
# 8      8225 2026-05-26      342     1098    Book P      11   72.57   4920.76
# 9      4449 2030-02-05      614     1086    Book M       5   15.67    714.58
# 10     3621 2036-05-08      755     1051     Boo E      19  149.75    100.70
# ...

# %%
data['CusterAge'][data['CusterAge'] < 0]
# Out:
# 4        -1
# 6        -4
# 30       -8
# 32       -1
# 47      -10
# 48       -6
# 64       -2
# 67       -6
# 74       -8
# 77       -6
# 99      -10
# 110      -9
# 154      -6
# 178      -3
# 181     -10
# 182      -7
# 191     -10
# 201      -8
# 206      -8
# 221      -5
# 222      -7
# 225      -3
# 242      -8
# 252      -3
# 261      -4
# 274      -4
# 283      -8
# 299      -1
# 300      -3
# 308      -3
#          ..
# 9825    -10
# 9830     -2
# 9851     -6
# 9866     -6
# 9869     -9
# 9896     -9
# 9904     -4
# 9906     -4
# 9919     -1
# 9936     -9
# 9946     -2
# 9966     -6
# 9979     -7
# 9983     -7
# 9986     -9
# 9988     -5
# 9995     -9
# 9997     -4
# 10019    -2
# 10020    -1
# 10024    -9
# 10027    -1
# 10030    -3
# 10033    -9
# 10038    -6
# 10065    -5
# 10068    -4
# 10075    -7
# 10080    -1
# 10098    -7
# Name: CusterAge, Length: 974, dtype: int64

# %%
data['CusterAge'][data['CusterAge'] < 0].value_counts()
# Out:
# -7     113
# -2     102
# -1     102
# -5      98
# -9      97
# -8      97
# -3      96
# -6      94
# -4      93
# -10     82
# Name: CusterAge, dtype: int64

# %%
data['CusterAge'][data['CusterAge'] < 0].value_counts().sum()
# Out:
# 974

# %%
data['CusterAge'].max()
# Out:
# 99

# %%
data['CusterAge'].min()
# Out:
# -10

# %%
len(data['CusterAge'][data['CusterAge'] < 18])
# Out:
# 2561

# %%
import numpy as np

# %%
d = np.random.randint(16, 25, size = 2561)

# %%
d
# Out:
# array([19, 18, 24, ..., 18, 23, 19])

# %%
data['CusterAge'][data['CusterAge'] < 18]
# Out:
# 2        15
# 4        -1
# 6        -4
# 15        9
# 30       -8
# 31       14
# 32       -1
# 38        6
# 40       12
# 47      -10
# 48       -6
# 59        8
# 63        4
# 64       -2
# 67       -6
# 72        0
# 74       -8
# 77       -6
# 79       12
# 80       16
# 81        7
# 91       11
# 98        2
# 99      -10
# 104      14
# 107       1
# 108      17
# 110      -9
# 120       1
# 129       4
#          ..
# 9991     17
# 9995     -9
# 9997     -4
# 10005    14
# 10007    17
# 10010     8
# 10019    -2
# 10020    -1
# 10023     3
# 10024    -9
# 10027    -1
# 10029     0
# 10030    -3
# 10033    -9
# 10035    12
# 10036    17
# 10038    -6
# 10048    16
# 10052    16
# 10065    -5
# 10068    -4
# 10074     2
# 10075    -7
# 10080    -1
# 10082    13
# 10083     3
# 10084     7
# 10090     3
# 10091     4
# 10098    -7
# Name: CusterAge, Length: 2561, dtype: int64

# %%
data['CusterAge'][data['CusterAge'] < 18] = d
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\USER\Anaconda3\lib\site-packages\pandas\core\generic.py:8682: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# C:\Users\USER\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3325: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
data['CusterAge'].unique()
# Out:
# array([87, 69, 19, 22, 18, 54, 24, 82, 51, 95, 86, 35, 25, 31, 74, 97, 56,
#        46, 71, 40, 77, 43, 57, 42, 65, 50, 23, 59, 39, 93, 20, 76, 58, 80,
#        63, 66, 16, 27, 99, 91, 68, 98, 96, 72, 17, 64, 29, 21, 75, 67, 92,
#        90, 36, 45, 41, 73, 81, 49, 89, 79, 30, 37, 38, 53, 84, 85, 26, 34,
#        28, 32, 61, 48, 52, 78, 60, 33, 44, 70, 88, 83, 62, 47, 94, 55],
#       dtype=int64)

# %%
data['CusterAge'].min()
# Out:
# 16

# %%
data['CusterAge'].max()
# Out:
# 99

# %%
data.sample()
# Out:
#       TrnsnID       Data  CusmrID  ProdtID ProdtName  Qutity   Prize  \
# 5240     4332 2027-11-01      526     1074    Book A       9  180.11
#
#       TtlSales PaymentType  CusterAge
# 5240   4684.85        Cash         19

# %%
data['Qutity'][data['Qutity'] < 0].value_counts().sum()
# Out:
# 1939

# %%
data['Qutity'].max()
# Out:
# 19

# %%
data['Qutity'].min()
# Out:
# -5

# %%
len(data['Qutity'][data['Qutity'] < 2])
# Out:
# 2803

# %%
import numpy as np
q = np.random.randint(2, size = 1939)

# %%
q
# Out:
# array([1, 0, 1, ..., 0, 0, 0])

# %%
data['Qutity'][data['Qutity'] < 0] = q
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data['Qutity'].unique()
# Out:
# array([ 9, 18,  5,  6, 15, 12, 11, 19, 14,  1, 10, 13,  8, 17,  2,  7,  3,
#         0, 16,  4], dtype=int64)

# %%
data.head(50)
# Out:
#     TrnsnID       Data  CusmrID  ProdtID ProdtName  Qutity   Prize  TtlSales  \
# 0      7402 2026-03-17      991     1045     Boo E       9  167.72   2935.06
# 1      5835 2035-01-26      741     1040    Book J      18  193.27   4386.52
# 2      2123 2035-05-26      933     1062     Bok N       5  126.39   1948.46
# 3      8789 2036-02-28      641     1060    Book I       6   66.98   1757.26
# 4       305 2023-04-19      123     1058    Book B      15   33.63   2578.19
# 5      2532 2032-08-19      185     1090     Bok N      12  102.69    488.23
# 6      2996 2031-04-03      571     1086    Book D      15  176.27   4822.26
# 7      7660 2031-02-27      172     1012    Book P      12   44.51   4966.85
# 8      8225 2026-05-26      342     1098    Book P      11   72.57   4920.76
# 9      4449 2030-02-05      614     1086    Book M       5   15.67    714.58
# 10     3621 2036-05-08      755     1051     Boo E      19  149.75    100.70
# ...

# %% [markdown]
# ## 6. Unrealistic Values

# %%
['Data', "TrnsnID", "CusmrID", "ProdtID", "ProdtName", "Qutity", "TtlSales", "CusterAge"]
# Out:
# ['Data',
#  'TrnsnID',
#  'CusmrID',
#  'ProdtID',
#  'ProdtName',
#  'Qutity',
#  'TtlSales',
#  'CusterAge']

# %% [markdown]
# ## 7. Typos

# %%
'Data', 'CusterAge', 'Boo E', 'Bok N', 'Bookk H'
# Out:
# ('Data', 'CusterAge', 'Boo E', 'Bok N', 'Bookk H')

# %% [markdown]
# ## 8. Typos in prodtName

# %%
data['ProdtName'].unique()
# Out:
# array(['Boo E', 'Book J', 'Bok N', 'Book I', 'Book B', 'Book D', 'Book P',
#        'Book M', 'Book O', 'Book T', 'Book A', 'Book G', 'Book R',
#        'Book L', 'Book K', 'Book F', 'Bookk H', 'Book S'], dtype=object)

# %%
data['ProdtName'].replace({'Boo E': 'Book E', 'Bok N': 'Book N', 'Bookk H': 'Book H'})
# Out:
# 0        Book E
# 1        Book J
# 2        Book N
# 3        Book I
# 4        Book B
# 5        Book N
# 6        Book D
# 7        Book P
# 8        Book P
# 9        Book M
# 10       Book E
# 11       Book O
# 12       Book I
# 13       Book T
# 14       Book A
# 15       Book T
# 17       Book G
# 18       Book J
# 19       Book G
# 21       Book P
# 22       Book B
# 23       Book R
# 24       Book M
# 25       Book J
# 26       Book N
# 27       Book G
# 28       Book G
# 29       Book G
# 30       Book P
# 31       Book L
#           ...
# 10070    Book F
# 10071    Book I
# 10072    Book E
# 10073    Book N
# 10074    Book I
# 10075    Book S
# 10076    Book I
# 10077    Book O
# 10078    Book K
# 10079    Book O
# 10080    Book R
# 10081    Book R
# 10082    Book N
# 10083    Book G
# 10084    Book J
# 10085    Book K
# 10086    Book I
# 10087    Book J
# 10088    Book R
# 10089    Book H
# 10090    Book E
# 10091    Book S
# 10092    Book E
# 10093    Book E
# ...

# %%
data['ProdtName'] = data['ProdtName'].replace({'Boo E': 'Book E', 'Bok N': 'Book N', 'Bookk H': 'Book H'})
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data['ProdtName'].unique()
# Out:
# array(['Book E', 'Book J', 'Book N', 'Book I', 'Book B', 'Book D',
#        'Book P', 'Book M', 'Book O', 'Book T', 'Book A', 'Book G',
#        'Book R', 'Book L', 'Book K', 'Book F', 'Book H', 'Book S'],
#       dtype=object)

# %% [markdown]
# ## 9

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 0 to 10099
# Data columns (total 10 columns):
# TrnsnID        10000 non-null int64
# Data           10000 non-null datetime64[ns]
# CusmrID        10000 non-null int64
# ProdtID        10000 non-null int64
# ProdtName      10000 non-null object
# Qutity         10000 non-null int64
# Prize          10000 non-null float64
# TtlSales       10000 non-null float64
# PaymentType    10000 non-null object
# CusterAge      10000 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(5), object(2)
# memory usage: 859.4+ KB

# %% [markdown]
# ## 10. Correction of column names

# %%
data.sample()
# Out:
#       TrnsnID       Data  CusmrID  ProdtID ProdtName  Qutity  Prize  TtlSales  \
# 2375     2499 2028-12-01      850     1070    Book M      14  96.69   4657.71
#
#      PaymentType  CusterAge
# 2375      paypal         82

# %%
data.rename(columns={'TrnsnID': 'TransactionID', 'Data': 'Date', 'CusmrID': 'CustomerID', 'ProdtID': 'ProductID', 'ProdtName': 'ProductName', 'Qutity': 'Quantity', 'Prize': 'Price', 'TtlSales': 'TotalSales', 'CusterAge': 'CustomerAge'}, inplace = True)
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\pandas\core\frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
data.sample()
# Out:
#       TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 4138           1371 2024-02-01         240       1022      Book A         5
#
#       Price  TotalSales  PaymentType  CustomerAge
# 4138  97.07      402.97  Credit Card           42

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 0 to 10099
# Data columns (total 10 columns):
# TransactionID    10000 non-null int64
# Date             10000 non-null datetime64[ns]
# CustomerID       10000 non-null int64
# ProductID        10000 non-null int64
# ProductName      10000 non-null object
# Quantity         10000 non-null int64
# Price            10000 non-null float64
# TotalSales       10000 non-null float64
# PaymentType      10000 non-null object
# CustomerAge      10000 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(5), object(2)
# memory usage: 859.4+ KB

# %%
data
# Out:
#        TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 0               7402 2026-03-17         991       1045      Book E         9
# 1               5835 2035-01-26         741       1040      Book J        18
# 2               2123 2035-05-26         933       1062      Book N         5
# 3               8789 2036-02-28         641       1060      Book I         6
# 4                305 2023-04-19         123       1058      Book B        15
# 5               2532 2032-08-19         185       1090      Book N        12
# 6               2996 2031-04-03         571       1086      Book D        15
# 7               7660 2031-02-27         172       1012      Book P        12
# 8               8225 2026-05-26         342       1098      Book P        11
# 9               4449 2030-02-05         614       1086      Book M         5
# 10              3621 2036-05-08         755       1051      Book E        19
# ...
